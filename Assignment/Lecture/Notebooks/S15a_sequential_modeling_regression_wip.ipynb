# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Deep Neural Networks
# ## Session 15a
#
# ### Using artificial data
#
# ## Sequential Modeling Regression
# <img src='../../prasami_images/prasami_color_tutorials_small.png' style = 'width:400px;' alt="By Pramod Sharma : pramod.sharma@prasami.com" align="left"/>

# %%
###-----------------
### Import Libraries
###-----------------

import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import tensorflow as tf

from utils.helper import fn_plot_tf_hist
# Out:
# 2024-07-20 10:55:51.152719: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-20 10:55:51.165594: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-20 10:55:51.169287: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-20 10:55:51.179149: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-20 10:55:52.036665: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
###----------------------
### Some basic parameters
###----------------------

inpDir = '../../input' # location where input data is stored
outDir = '../output' # location to store outputs

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible  results
tf.random.set_seed(RANDOM_STATE) # setting for Tensorflow as well

EPOCHS = 50

BATCH_SIZE = 64
# Set parameters for decoration of plots
params = {'legend.fontsize': 'medium',
          'figure.figsize': (15, 6),
          'axes.labelsize': 'large',
          'axes.titlesize':'large',
          'xtick.labelsize':'medium',
          'ytick.labelsize':'medium'
         }

CMAP = plt.cm.coolwarm

plt.rcParams.update(params) # update rcParams

# %% [markdown]
# ## Basic Hygiene

# %%
physical_devices = tf.config.list_physical_devices('GPU') 

if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1721453152.585775   75805 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1721453152.629774   75805 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1721453152.634102   75805 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %% [markdown]
# ## Create Some Regression data

# %%
start = -2.1
end = 2.1

### Training data

delta = 0.0005

X_train = np.arange(start, end+ delta,delta)
y_rnd = np.random.rand(X_train.shape[0]) - 0.5
y_true =   2* np.square(X_train) + 2 * np.sin(np.pi*X_train)
y_train = y_true + y_rnd* 2

### Test data
X_test = np.arange(start, end+ delta, delta * 10 )
y_rnd = np.random.rand(X_test.shape[0])- 0.5
y_true_test =   2* np.square(X_test) + 2 * np.sin(np.pi*X_test)
y_test = y_true_test  + y_rnd* 2

# %%
num_examples = BATCH_SIZE * 131

X_train = X_train[:num_examples]
y_train = y_train[:num_examples]
y_true = y_true[:num_examples]

# %%
X_train.shape
# Out:
# (8384,)

# %%
X_train.max(), X_test.max()
# Out:
# (2.0915000000013992, 2.0999999999999104)

# %%
start = -2
end = 2
delta_train = 0.01

fig, axes = plt.subplots(1, 2, figsize =(15,5))

ax = axes[0]
ax.plot(X_train, y_train, 'b*', markersize=2, label = 'Train')
ax.plot(X_train,  y_true, c = 'k', linewidth=2, label = 'True')
ax.axhline(0, c = 'k')
ax.axvline(0, c = 'k')
ax.grid()
ax.legend()

ax = axes[1]
ax.plot(X_test, y_test, 'g*', markersize=2, label = 'Test')
ax.plot(X_test,  y_true_test, c = 'k', linewidth=2, label = 'True')
ax.axhline(0, c = 'k')
ax.axvline(0, c = 'k')
ax.grid()
ax.legend();

# %%
# What shape of Input layer?
num_features = 1

#initializer = tf.keras.initializers.HeNormal(seed = RANDOM_STATE)

# Define Model

# Define the input layer
input_layer = tf.keras.layers.Input(shape=(1,))  # Assuming input shape is (784,)

# Add a hidden layer with 128 neurons and ReLU activation
hidden_layer = tf.keras.layers.Dense(128, activation='relu')(input_layer)

# Add another hidden layer with 64 neurons and ReLU activation
hidden_layer = tf.keras.layers.Dense(64, activation='relu')(hidden_layer)

# Add the output layer with 10 neurons (for a classification task) and softmax activation
output_layer = tf.keras.layers.Dense(1)(hidden_layer)

# Create the model by specifying the input and output layers
model = tf.keras.Model(inputs=input_layer, outputs=output_layer)
# Out:
# I0000 00:00:1721453152.918587   75805 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1721453152.922993   75805 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1721453152.927124   75805 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1721453153.079327   75805 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1721453153.081432   75805 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1721453153.083334   75805 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-20 10:55:53.085218: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3610 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# Compile the model with a specific optimizer, loss function, and metrics

model.compile(optimizer='adam', 
              loss='mean_squared_error', 
              metrics=['mae'])

# %%
# fit the model
history = model.fit(X_train, y_train, 
                    batch_size = BATCH_SIZE,
                    validation_data=[X_test, y_test],
                    epochs=EPOCHS, 
                    verbose=2)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1721453153.687496   75887 service.cc:146] XLA service 0x70716c009e30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1721453153.687522   75887 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2024-07-20 10:55:53.703841: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-07-20 10:55:53.795806: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8902
# I0000 00:00:1721453155.219368   75887 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 131/131 - 3s - 22ms/step - loss: 5.7784 - mae: 1.8640 - val_loss: 2.4567 - val_mae: 1.2876
# Epoch 2/50
# 131/131 - 0s - 923us/step - loss: 1.7907 - mae: 1.0812 - val_loss: 1.3369 - val_mae: 0.9019
# Epoch 3/50
# 131/131 - 0s - 917us/step - loss: 1.2621 - mae: 0.8770 - val_loss: 1.2241 - val_mae: 0.8510
# Epoch 4/50
# 131/131 - 0s - 946us/step - loss: 1.1852 - mae: 0.8432 - val_loss: 1.1659 - val_mae: 0.8310
# Epoch 5/50
# 131/131 - 0s - 1ms/step - loss: 1.1102 - mae: 0.8196 - val_loss: 1.0715 - val_mae: 0.8035
# Epoch 6/50
# 131/131 - 0s - 958us/step - loss: 1.0077 - mae: 0.7884 - val_loss: 0.9570 - val_mae: 0.7696
# Epoch 7/50
# 131/131 - 0s - 858us/step - loss: 0.8916 - mae: 0.7501 - val_loss: 0.8341 - val_mae: 0.7277
# Epoch 8/50
# 131/131 - 0s - 849us/step - loss: 0.7750 - mae: 0.7065 - val_loss: 0.7162 - val_mae: 0.6833
# Epoch 9/50
# 131/131 - 0s - 896us/step - loss: 0.6690 - mae: 0.6617 - val_loss: 0.6137 - val_mae: 0.6418
# Epoch 10/50
# 131/131 - 0s - 883us/step - loss: 0.5779 - mae: 0.6202 - val_loss: 0.5285 - val_mae: 0.6035
# Epoch 11/50
# 131/131 - 0s - 982us/step - loss: 0.5033 - mae: 0.5849 - val_loss: 0.4618 - val_mae: 0.5715
# Epoch 12/50
# 131/131 - 0s - 981us/step - loss: 0.4468 - mae: 0.5567 - val_loss: 0.4148 - val_mae: 0.5461
# Epoch 13/50
# 131/131 - 0s - 973us/step - loss: 0.4096 - mae: 0.5382 - val_loss: 0.3863 - val_mae: 0.5302
# Epoch 14/50
# 131/131 - 0s - 989us/step - loss: 0.3876 - mae: 0.5273 - val_loss: 0.3715 - val_mae: 0.5225
# Epoch 15/50
# 131/131 - 0s - 992us/step - loss: 0.3756 - mae: 0.5216 - val_loss: 0.3636 - val_mae: 0.5181
# Epoch 16/50
# 131/131 - 0s - 988us/step - loss: 0.3680 - mae: 0.5179 - val_loss: 0.3583 - val_mae: 0.5156
# Epoch 17/50
# 131/131 - 0s - 1ms/step - loss: 0.3626 - mae: 0.5152 - val_loss: 0.3545 - val_mae: 0.5137
# Epoch 18/50
# 131/131 - 0s - 997us/step - loss: 0.3590 - mae: 0.5135 - val_loss: 0.3521 - val_mae: 0.5123
# Epoch 19/50
# 131/131 - 0s - 963us/step - loss: 0.3565 - mae: 0.5123 - val_loss: 0.3507 - val_mae: 0.5117
# Epoch 20/50
# 131/131 - 0s - 916us/step - loss: 0.3544 - mae: 0.5113 - val_loss: 0.3496 - val_mae: 0.5114
# Epoch 21/50
# 131/131 - 0s - 951us/step - loss: 0.3532 - mae: 0.5108 - val_loss: 0.3491 - val_mae: 0.5115
# Epoch 22/50
# 131/131 - 0s - 1ms/step - loss: 0.3524 - mae: 0.5104 - val_loss: 0.3485 - val_mae: 0.5114
# Epoch 23/50
# 131/131 - 0s - 1ms/step - loss: 0.3517 - mae: 0.5101 - val_loss: 0.3478 - val_mae: 0.5113
# Epoch 24/50
# 131/131 - 0s - 1ms/step - loss: 0.3513 - mae: 0.5100 - val_loss: 0.3477 - val_mae: 0.5112
# Epoch 25/50
# 131/131 - 0s - 1ms/step - loss: 0.3510 - mae: 0.5099 - val_loss: 0.3476 - val_mae: 0.5113
# Epoch 26/50
# 131/131 - 0s - 998us/step - loss: 0.3506 - mae: 0.5098 - val_loss: 0.3475 - val_mae: 0.5113
# Epoch 27/50
# 131/131 - 0s - 1ms/step - loss: 0.3504 - mae: 0.5097 - val_loss: 0.3475 - val_mae: 0.5114
# Epoch 28/50
# 131/131 - 0s - 1ms/step - loss: 0.3502 - mae: 0.5097 - val_loss: 0.3474 - val_mae: 0.5115
# Epoch 29/50
# 131/131 - 0s - 1ms/step - loss: 0.3499 - mae: 0.5095 - val_loss: 0.3471 - val_mae: 0.5114
# Epoch 30/50
# 131/131 - 0s - 960us/step - loss: 0.3498 - mae: 0.5095 - val_loss: 0.3468 - val_mae: 0.5112
# Epoch 31/50
# 131/131 - 0s - 917us/step - loss: 0.3496 - mae: 0.5094 - val_loss: 0.3464 - val_mae: 0.5109
# Epoch 32/50
# 131/131 - 0s - 920us/step - loss: 0.3495 - mae: 0.5093 - val_loss: 0.3463 - val_mae: 0.5109
# Epoch 33/50
# 131/131 - 0s - 947us/step - loss: 0.3495 - mae: 0.5094 - val_loss: 0.3463 - val_mae: 0.5110
# Epoch 34/50
# 131/131 - 0s - 935us/step - loss: 0.3494 - mae: 0.5093 - val_loss: 0.3463 - val_mae: 0.5110
# Epoch 35/50
# 131/131 - 0s - 925us/step - loss: 0.3493 - mae: 0.5093 - val_loss: 0.3461 - val_mae: 0.5109
# Epoch 36/50
# 131/131 - 0s - 925us/step - loss: 0.3491 - mae: 0.5092 - val_loss: 0.3462 - val_mae: 0.5110
# Epoch 37/50
# 131/131 - 0s - 1ms/step - loss: 0.3490 - mae: 0.5091 - val_loss: 0.3462 - val_mae: 0.5110
# Epoch 38/50
# 131/131 - 0s - 972us/step - loss: 0.3490 - mae: 0.5091 - val_loss: 0.3462 - val_mae: 0.5111
# Epoch 39/50
# 131/131 - 0s - 996us/step - loss: 0.3489 - mae: 0.5091 - val_loss: 0.3463 - val_mae: 0.5112
# Epoch 40/50
# 131/131 - 0s - 903us/step - loss: 0.3489 - mae: 0.5091 - val_loss: 0.3462 - val_mae: 0.5112
# Epoch 41/50
# 131/131 - 0s - 900us/step - loss: 0.3489 - mae: 0.5091 - val_loss: 0.3463 - val_mae: 0.5113
# Epoch 42/50
# 131/131 - 0s - 849us/step - loss: 0.3488 - mae: 0.5090 - val_loss: 0.3464 - val_mae: 0.5113
# Epoch 43/50
# 131/131 - 0s - 1ms/step - loss: 0.3488 - mae: 0.5090 - val_loss: 0.3463 - val_mae: 0.5113
# Epoch 44/50
# 131/131 - 0s - 893us/step - loss: 0.3487 - mae: 0.5090 - val_loss: 0.3462 - val_mae: 0.5112
# Epoch 45/50
# 131/131 - 0s - 912us/step - loss: 0.3486 - mae: 0.5090 - val_loss: 0.3463 - val_mae: 0.5113
# Epoch 46/50
# 131/131 - 0s - 876us/step - loss: 0.3486 - mae: 0.5089 - val_loss: 0.3465 - val_mae: 0.5114
# Epoch 47/50
# 131/131 - 0s - 865us/step - loss: 0.3485 - mae: 0.5089 - val_loss: 0.3462 - val_mae: 0.5113
# Epoch 48/50
# 131/131 - 0s - 873us/step - loss: 0.3485 - mae: 0.5089 - val_loss: 0.3464 - val_mae: 0.5113
# Epoch 49/50
# 131/131 - 0s - 883us/step - loss: 0.3484 - mae: 0.5089 - val_loss: 0.3463 - val_mae: 0.5113
# Epoch 50/50
# 131/131 - 0s - 889us/step - loss: 0.3484 - mae: 0.5089 - val_loss: 0.3463 - val_mae: 0.5113

# %%
hist_df = pd.DataFrame(history.history)

fn_plot_tf_hist(hist_df)

# %%
# evaluate the model
error = model.evaluate(X_test, y_test, verbose=0)

print(f'Loss: {error[0]:.3f}, MAE: {np.sqrt(error[1]):.3f}')
# Out:
# Loss: 0.346, MAE: 0.715

# %%
y_pred = model.predict(X_test)

results_df = pd.DataFrame({'pred' : y_pred[:,0], 'test' : y_test} )

results_df['y_true'] = y_true_test
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
ax = results_df.pred.plot(c = 'r', label = 'pred');
results_df.y_true.plot(c = 'k', ax = ax, label = 'true')

plt.scatter(results_df.index, results_df.test, c='DarkBlue', marker ='*', label = 'test');
ax.set_xlabel("epoch")
ax.set_ylabel("Price")
ax.grid()
plt.legend()
plt.show()

# %%
# What shape of Input layer?
num_features = 1

initializer = tf.keras.initializers.HeNormal(seed = RANDOM_STATE)

# define model
model = tf.keras.Sequential()

model.add( tf.keras.layers.Dense(128, 
                                 activation='swish', 
                                 kernel_initializer=initializer, 
                                 input_shape=(num_features,)))

model.add(tf.keras.layers.Dense(64, 
                                activation='swish', 
                                kernel_initializer=initializer))

model.add(tf.keras.layers.Dense(1))
# Out:
# /home/pks/Sep2024/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# compile the model
model.compile(optimizer='adam', loss='mse')

# %%
# fit the model
history = model.fit(X_train, y_train, 
          batch_size = BATCH_SIZE,
          validation_data=[X_test, y_test],
          epochs=EPOCHS, 
          verbose=2)
# Out:
# Epoch 1/50
# 131/131 - 1s - 8ms/step - loss: 2.0571 - val_loss: 1.0255
# Epoch 2/50
# 131/131 - 0s - 870us/step - loss: 0.9165 - val_loss: 0.7712
# Epoch 3/50
# 131/131 - 0s - 857us/step - loss: 0.7281 - val_loss: 0.6457
# Epoch 4/50
# 131/131 - 0s - 874us/step - loss: 0.6367 - val_loss: 0.5747
# Epoch 5/50
# 131/131 - 0s - 1ms/step - loss: 0.5756 - val_loss: 0.5258
# Epoch 6/50
# 131/131 - 0s - 906us/step - loss: 0.5243 - val_loss: 0.4982
# Epoch 7/50
# 131/131 - 0s - 878us/step - loss: 0.4835 - val_loss: 0.4874
# Epoch 8/50
# 131/131 - 0s - 857us/step - loss: 0.4513 - val_loss: 0.4776
# Epoch 9/50
# 131/131 - 0s - 883us/step - loss: 0.4251 - val_loss: 0.4679
# Epoch 10/50
# 131/131 - 0s - 882us/step - loss: 0.4060 - val_loss: 0.4556
# Epoch 11/50
# 131/131 - 0s - 904us/step - loss: 0.3932 - val_loss: 0.4427
# Epoch 12/50
# 131/131 - 0s - 861us/step - loss: 0.3848 - val_loss: 0.4329
# Epoch 13/50
# 131/131 - 0s - 852us/step - loss: 0.3793 - val_loss: 0.4262
# Epoch 14/50
# 131/131 - 0s - 861us/step - loss: 0.3757 - val_loss: 0.4217
# Epoch 15/50
# 131/131 - 0s - 870us/step - loss: 0.3734 - val_loss: 0.4188
# Epoch 16/50
# 131/131 - 0s - 886us/step - loss: 0.3719 - val_loss: 0.4167
# Epoch 17/50
# 131/131 - 0s - 852us/step - loss: 0.3706 - val_loss: 0.4151
# Epoch 18/50
# 131/131 - 0s - 842us/step - loss: 0.3696 - val_loss: 0.4136
# Epoch 19/50
# 131/131 - 0s - 842us/step - loss: 0.3687 - val_loss: 0.4125
# Epoch 20/50
# 131/131 - 0s - 848us/step - loss: 0.3681 - val_loss: 0.4115
# Epoch 21/50
# 131/131 - 0s - 842us/step - loss: 0.3675 - val_loss: 0.4106
# Epoch 22/50
# 131/131 - 0s - 856us/step - loss: 0.3669 - val_loss: 0.4098
# Epoch 23/50
# 131/131 - 0s - 851us/step - loss: 0.3664 - val_loss: 0.4090
# Epoch 24/50
# 131/131 - 0s - 852us/step - loss: 0.3659 - val_loss: 0.4083
# Epoch 25/50
# 131/131 - 0s - 860us/step - loss: 0.3654 - val_loss: 0.4076
# Epoch 26/50
# 131/131 - 0s - 859us/step - loss: 0.3649 - val_loss: 0.4069
# Epoch 27/50
# 131/131 - 0s - 866us/step - loss: 0.3645 - val_loss: 0.4062
# Epoch 28/50
# 131/131 - 0s - 860us/step - loss: 0.3641 - val_loss: 0.4056
# Epoch 29/50
# 131/131 - 0s - 835us/step - loss: 0.3637 - val_loss: 0.4050
# Epoch 30/50
# 131/131 - 0s - 898us/step - loss: 0.3633 - val_loss: 0.4044
# Epoch 31/50
# 131/131 - 0s - 890us/step - loss: 0.3629 - val_loss: 0.4038
# Epoch 32/50
# 131/131 - 0s - 867us/step - loss: 0.3625 - val_loss: 0.4031
# Epoch 33/50
# 131/131 - 0s - 866us/step - loss: 0.3621 - val_loss: 0.4024
# Epoch 34/50
# 131/131 - 0s - 863us/step - loss: 0.3618 - val_loss: 0.4017
# Epoch 35/50
# 131/131 - 0s - 880us/step - loss: 0.3614 - val_loss: 0.4010
# Epoch 36/50
# 131/131 - 0s - 845us/step - loss: 0.3611 - val_loss: 0.4003
# Epoch 37/50
# 131/131 - 0s - 850us/step - loss: 0.3608 - val_loss: 0.3996
# Epoch 38/50
# 131/131 - 0s - 862us/step - loss: 0.3605 - val_loss: 0.3989
# Epoch 39/50
# 131/131 - 0s - 862us/step - loss: 0.3602 - val_loss: 0.3981
# Epoch 40/50
# 131/131 - 0s - 852us/step - loss: 0.3599 - val_loss: 0.3973
# Epoch 41/50
# 131/131 - 0s - 843us/step - loss: 0.3597 - val_loss: 0.3965
# Epoch 42/50
# 131/131 - 0s - 850us/step - loss: 0.3594 - val_loss: 0.3956
# Epoch 43/50
# 131/131 - 0s - 850us/step - loss: 0.3592 - val_loss: 0.3948
# Epoch 44/50
# 131/131 - 0s - 888us/step - loss: 0.3589 - val_loss: 0.3939
# Epoch 45/50
# 131/131 - 0s - 867us/step - loss: 0.3587 - val_loss: 0.3929
# Epoch 46/50
# 131/131 - 0s - 848us/step - loss: 0.3584 - val_loss: 0.3919
# Epoch 47/50
# 131/131 - 0s - 865us/step - loss: 0.3582 - val_loss: 0.3909
# Epoch 48/50
# 131/131 - 0s - 882us/step - loss: 0.3580 - val_loss: 0.3899
# Epoch 49/50
# 131/131 - 0s - 874us/step - loss: 0.3578 - val_loss: 0.3889
# Epoch 50/50
# 131/131 - 0s - 865us/step - loss: 0.3576 - val_loss: 0.3878

# %%
fn_plot_tf_hist(pd.DataFrame(hist_df))

# %%
y_pred = model.predict(X_test)

results_df = pd.DataFrame({'pred' : y_pred[:, 0], 'test' : y_test} )

results_df['y_true'] = y_true_test
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
ax = results_df.pred.plot(c = 'r', label = 'pred');
results_df.y_true.plot(c = 'k', ax = ax, label = 'true')

plt.scatter(results_df.index, results_df.test, c='DarkBlue', marker ='*', label = 'test');
ax.set_xlabel("epoch")
ax.set_ylabel("Price")
ax.grid()
plt.legend()
plt.show()
