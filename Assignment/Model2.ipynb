# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, Flatten, Dense, 
    Dropout, BatchNormalization, Input, 
    LeakyReLU, RandomFlip, RandomRotation, 
    RandomZoom, Rescaling
)
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import (
    ModelCheckpoint, 
    EarlyStopping, 
    ReduceLROnPlateau, 
    CSVLogger
)

# %%
# Seed for reproducibility
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
tf.random.set_seed(RANDOM_STATE)

# Hyperparameters
IMG_HEIGHT = 224  # Increased from original 188
IMG_WIDTH = 224   # Increased from original 188
BATCH_SIZE = 8
EPOCHS = 50       # Increased from original
TEST_SIZE = 0.2
LEARNING_RATE = 1e-4  # Adjusted learning rate
PATIENCE = 15     # Increased patience
L2_RATE = 1e-4    # L2 regularization

# %%
# Directories
BASE_DIR = '../'
INPUT_DIR = os.path.join(BASE_DIR, 'input')
OUTPUT_DIR = os.path.join(BASE_DIR, 'output')
MODEL_DIR = os.path.join(BASE_DIR, 'models')
SUBDIR = 'flower_photos'

# Ensure directories exist
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)

# %%
# Load and preprocess dataset
def load_dataset(data_dir):
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
        data_dir,
        subset="training",
        seed=RANDOM_STATE,
        image_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=BATCH_SIZE,
        validation_split=TEST_SIZE,
    )

    test_ds = tf.keras.preprocessing.image_dataset_from_directory(
        data_dir,
        subset="validation",
        seed=RANDOM_STATE,
        image_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=BATCH_SIZE,
        validation_split=TEST_SIZE,
    )
    
    return train_ds, test_ds

# %%
# Load and preprocess dataset
def load_dataset(data_dir):
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
        data_dir,
        subset="training",
        seed=RANDOM_STATE,
        image_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=BATCH_SIZE,
        validation_split=TEST_SIZE,
    )

    test_ds = tf.keras.preprocessing.image_dataset_from_directory(
        data_dir,
        subset="validation",
        seed=RANDOM_STATE,
        image_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=BATCH_SIZE,
        validation_split=TEST_SIZE,
    )
    
    return train_ds, test_ds

# %%
# Performance optimization for dataset
def configure_dataset(ds, augment=False):
    if augment:
        # Data augmentation layers
        data_augmentation = tf.keras.Sequential([
            RandomFlip('horizontal'),
            RandomRotation(0.2),
            RandomZoom(0.2),
        ])
        
        ds = ds.map(
            lambda x, y: (data_augmentation(x, training=True), y), 
            num_parallel_calls=tf.data.AUTOTUNE
        )
    
    return ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# Create advanced custom CNN model
def create_custom_cnn_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    
    # Preprocessing and augmentation
    x = Rescaling(1./255)(inputs)
    
    # First Convolutional Block
    x = Conv2D(64, (3,3), padding='same')(x)
    x = LeakyReLU(negative_slope=0.1)(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2,2), padding='same')(x)
    x = Dropout(0.25)(x)
    
    # Second Convolutional Block
    x = Conv2D(128, (3,3), padding='valid')(x)
    x = LeakyReLU(negative_slope=0.1)(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2,2), padding='valid')(x)
    x = Dropout(0.3)(x)
    
    # Third Convolutional Block
    x = Conv2D(256, (3,3), padding='valid')(x)
    x = LeakyReLU(negative_slope=0.1)(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2,2), padding='valid')(x)
    x = Dropout(0.35)(x)
    
    # Fourth Convolutional Block
    x = Conv2D(512, (3,3), padding='valid')(x)
    x = LeakyReLU(negative_slope=0.1)(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2,2), padding='valid')(x)
    x = Dropout(0.4)(x)
    
    # Fifth Convolutional Block
    x = Conv2D(1024, (3,3), padding='valid')(x)
    x = LeakyReLU(negative_slope=0.1)(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)
    
    # Fully Connected Layers 
    x = Flatten()(x)
    
    # Head Layers
    x = Dense(1024)(x)
    x = LeakyReLU(negative_slope=0.1)(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    
    x = Dense(256)(x)
    x = LeakyReLU(negative_slope=0.1)(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    
    # Output Layer
    outputs = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
# Main training function
def train_model():
    # Load dataset
    data_dir = os.path.join(INPUT_DIR, SUBDIR)
    train_ds, test_ds = load_dataset(data_dir)
    
    # Get class names
    class_names = train_ds.class_names
    num_classes = len(class_names)
    
    # Configure datasets
    train_ds = configure_dataset(train_ds, augment=True)
    test_ds = configure_dataset(test_ds)
    
    # Create model
    model = create_custom_cnn_model(
        input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), 
        num_classes=num_classes
    )
    
    # Model Summary
    model.summary()
    
    # Compile model
    model.compile(
        optimizer=Adam(learning_rate=LEARNING_RATE),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    
    # Callbacks
    # checkpoint_path = os.path.join(MODEL_DIR, SUBDIR, 'best_custom_model.keras')
    checkpoint_path = os.path.normpath(os.path.join(MODEL_DIR, SUBDIR, 'best_custom_model.keras'))

    os.makedirs(os.path.dirname(checkpoint_path), exist_ok=True)
    
    model_checkpoint = ModelCheckpoint(
        checkpoint_path,
        monitor='val_accuracy',
        mode='max',
        save_best_only=True,
        verbose=1
    )
    
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=PATIENCE,
        restore_best_weights=True,
        verbose=1
    )
    
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=8,
        min_lr=1e-6,
        verbose=1
    )
    
    csv_logger = CSVLogger(
        os.path.join(OUTPUT_DIR, 'custom_cnn_training_log.csv'), 
        separator=',', 
        append=False
    )
    
    # Train model
    history = model.fit(
        train_ds, 
        epochs=EPOCHS, 
        validation_data=test_ds,
        callbacks=[
            model_checkpoint, 
            early_stopping, 
            reduce_lr,
            csv_logger
        ]
    )
    
    # Evaluate model
    test_loss, test_accuracy = model.evaluate(test_ds)
    print(f'Test accuracy: {test_accuracy * 100:.2f}%')
    
    # Plot training history
    plt.figure(figsize=(12, 4))
    
    # Accuracy plot
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    
    # Loss plot
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIR, 'custom_cnn_training_history.png'))
    plt.close()
    
    return model, history

# %%
# Run the training
if __name__ == '__main__':
    model, history = train_model()
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 224, 224, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 110, 110, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 110, 110, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 110, 110, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 55, 55, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 55, 55, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 53, 53, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 53, 53, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 53, 53, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 26, 26, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 26, 26, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 24, 24, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 24, 24, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 24, 24, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 12, 12, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 12, 12, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 10, 10, 1024)   │     4,719,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_4 (LeakyReLU)       │ (None, 10, 10, 1024)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 10, 10, 1024)   │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 10, 10, 1024)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 102400)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │   104,858,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_5 (LeakyReLU)       │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_6 (LeakyReLU)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 111,405,957 (424.98 MB)
#  Trainable params: 111,399,429 (424.96 MB)
#  Non-trainable params: 6,528 (25.50 KB)
# Epoch 1/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3345 - loss: 2.2337
# Epoch 1: val_accuracy improved from -inf to 0.27793, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 577s 2s/step - accuracy: 0.3346 - loss: 2.2333 - val_accuracy: 0.2779 - val_loss: 3.1799 - learning_rate: 1.0000e-04
# Epoch 2/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4227 - loss: 1.8368
# Epoch 2: val_accuracy improved from 0.27793 to 0.36648, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 570s 2s/step - accuracy: 0.4227 - loss: 1.8367 - val_accuracy: 0.3665 - val_loss: 2.3047 - learning_rate: 1.0000e-04
# Epoch 3/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4599 - loss: 1.6707
# Epoch 3: val_accuracy did not improve from 0.36648
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 559s 2s/step - accuracy: 0.4599 - loss: 1.6706 - val_accuracy: 0.3433 - val_loss: 2.8628 - learning_rate: 1.0000e-04
# Epoch 4/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4826 - loss: 1.5490
# Epoch 4: val_accuracy improved from 0.36648 to 0.39237, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 567s 2s/step - accuracy: 0.4826 - loss: 1.5491 - val_accuracy: 0.3924 - val_loss: 2.7224 - learning_rate: 1.0000e-04
# Epoch 5/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5162 - loss: 1.4582
# Epoch 5: val_accuracy improved from 0.39237 to 0.40191, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 571s 2s/step - accuracy: 0.5162 - loss: 1.4582 - val_accuracy: 0.4019 - val_loss: 2.5005 - learning_rate: 1.0000e-04
# Epoch 6/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5162 - loss: 1.4063
# Epoch 6: val_accuracy improved from 0.40191 to 0.42643, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 565s 2s/step - accuracy: 0.5163 - loss: 1.4063 - val_accuracy: 0.4264 - val_loss: 2.2035 - learning_rate: 1.0000e-04
# Epoch 7/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5500 - loss: 1.2564
# Epoch 7: val_accuracy improved from 0.42643 to 0.46049, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 565s 2s/step - accuracy: 0.5500 - loss: 1.2565 - val_accuracy: 0.4605 - val_loss: 1.9569 - learning_rate: 1.0000e-04
# Epoch 8/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5730 - loss: 1.2413
# Epoch 8: val_accuracy did not improve from 0.46049
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 565s 2s/step - accuracy: 0.5730 - loss: 1.2412 - val_accuracy: 0.4346 - val_loss: 2.0955 - learning_rate: 1.0000e-04
# Epoch 9/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5878 - loss: 1.1727
# Epoch 9: val_accuracy did not improve from 0.46049
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 563s 2s/step - accuracy: 0.5878 - loss: 1.1726 - val_accuracy: 0.4305 - val_loss: 2.0493 - learning_rate: 1.0000e-04
# Epoch 10/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6163 - loss: 1.0716
# Epoch 10: val_accuracy improved from 0.46049 to 0.50000, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 585s 2s/step - accuracy: 0.6164 - loss: 1.0717 - val_accuracy: 0.5000 - val_loss: 1.5298 - learning_rate: 1.0000e-04
# Epoch 11/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6298 - loss: 1.0226
# Epoch 11: val_accuracy improved from 0.50000 to 0.51226, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 591s 2s/step - accuracy: 0.6298 - loss: 1.0226 - val_accuracy: 0.5123 - val_loss: 1.6925 - learning_rate: 1.0000e-04
# Epoch 12/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6395 - loss: 0.9514
# Epoch 12: val_accuracy improved from 0.51226 to 0.51362, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 583s 2s/step - accuracy: 0.6396 - loss: 0.9514 - val_accuracy: 0.5136 - val_loss: 1.9487 - learning_rate: 1.0000e-04
# Epoch 13/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6802 - loss: 0.8761
# Epoch 13: val_accuracy improved from 0.51362 to 0.52589, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 583s 2s/step - accuracy: 0.6802 - loss: 0.8761 - val_accuracy: 0.5259 - val_loss: 1.8376 - learning_rate: 1.0000e-04
# Epoch 14/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7011 - loss: 0.8322
# Epoch 14: val_accuracy improved from 0.52589 to 0.57766, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 580s 2s/step - accuracy: 0.7011 - loss: 0.8322 - val_accuracy: 0.5777 - val_loss: 1.4344 - learning_rate: 1.0000e-04
# Epoch 15/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7269 - loss: 0.7232
# Epoch 15: val_accuracy did not improve from 0.57766
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 576s 2s/step - accuracy: 0.7269 - loss: 0.7233 - val_accuracy: 0.5368 - val_loss: 1.7309 - learning_rate: 1.0000e-04
# Epoch 16/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7484 - loss: 0.6585
# Epoch 16: val_accuracy improved from 0.57766 to 0.57902, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 567s 2s/step - accuracy: 0.7485 - loss: 0.6585 - val_accuracy: 0.5790 - val_loss: 1.6982 - learning_rate: 1.0000e-04
# Epoch 17/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7685 - loss: 0.6175
# Epoch 17: val_accuracy improved from 0.57902 to 0.58174, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 563s 2s/step - accuracy: 0.7685 - loss: 0.6174 - val_accuracy: 0.5817 - val_loss: 1.7962 - learning_rate: 1.0000e-04
# Epoch 18/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8019 - loss: 0.5079
# Epoch 18: val_accuracy improved from 0.58174 to 0.63215, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 567s 2s/step - accuracy: 0.8019 - loss: 0.5078 - val_accuracy: 0.6322 - val_loss: 1.5332 - learning_rate: 1.0000e-04
# Epoch 19/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8233 - loss: 0.4625
# Epoch 19: val_accuracy did not improve from 0.63215
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 557s 2s/step - accuracy: 0.8233 - loss: 0.4625 - val_accuracy: 0.5858 - val_loss: 1.8537 - learning_rate: 1.0000e-04
# Epoch 20/50
# 178/367 ━━━━━━━━━━━━━━━━━━━━ 4:36 1s/step - accuracy: 0.8334 - loss: 0.3993
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Run the training
#       2 if __name__ == '__main__':
# ----> 3     model, history = train_model()
#
# Cell In[8], line 67, in train_model()
#      60 csv_logger = CSVLogger(
#      61     os.path.join(OUTPUT_DIR, 'custom_cnn_training_log.csv'),
#      62     separator=',',
#      63     append=False
#      64 )
#      66 # Train model
# ---> 67 history = model.fit(
#      68     train_ds,
#      69     epochs=EPOCHS,
#      70     validation_data=test_ds,
#      71     callbacks=[
#      72         model_checkpoint,
#      73         early_stopping,
#      74         reduce_lr,
#      75         csv_logger
#      76     ]
#      77 )
#      79 # Evaluate model
#      80 test_loss, test_accuracy = model.evaluate(test_ds)
#
# File c:\Users\DAI.STUDENTSDC\.conda\envs\pythonProject\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\DAI.STUDENTSDC\.conda\envs\pythonProject\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:320, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318 for step, iterator in epoch_iterator.enumerate_epoch():
#     319     callbacks.on_train_batch_begin(step)
# --> 320     logs = self.train_function(iterator)
#     321     callbacks.on_train_batch_end(step, logs)
#     322     if self.stop_training:
#
# File c:\Users\DAI.STUDENTSDC\.conda\envs\pythonProject\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\DAI.STUDENTSDC\.conda\envs\pythonProject\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\DAI.STUDENTSDC\.conda\envs\pythonProject\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\DAI.STUDENTSDC\.conda\envs\pythonProject\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\DAI.STUDENTSDC\.conda\envs\pythonProject\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\DAI.STUDENTSDC\.conda\envs\pythonProject\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\DAI.STUDENTSDC\.conda\envs\pythonProject\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\DAI.STUDENTSDC\.conda\envs\pythonProject\Lib\site-packages\tensorflow\python\eager\context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)
#    1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File c:\Users\DAI.STUDENTSDC\.conda\envs\pythonProject\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
