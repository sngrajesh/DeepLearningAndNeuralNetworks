# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, Flatten, Dense, 
    Dropout, BatchNormalization, Input, 
    LeakyReLU, RandomFlip, RandomRotation, 
    RandomZoom, Rescaling
)
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import (
    ModelCheckpoint, 
    EarlyStopping, 
    ReduceLROnPlateau, 
    CSVLogger
)

# %%
# Seed for reproducibility
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
tf.random.set_seed(RANDOM_STATE)

# Hyperparameters
IMG_HEIGHT = 224  # Increased from original 188
IMG_WIDTH = 224   # Increased from original 188
BATCH_SIZE = 8
EPOCHS = 50       # Increased from original
TEST_SIZE = 0.2
LEARNING_RATE = 1e-4  # Adjusted learning rate
PATIENCE = 15     # Increased patience
L2_RATE = 1e-4    # L2 regularization

# %%
# Directories
BASE_DIR = '../'
INPUT_DIR = os.path.join(BASE_DIR, 'input')
OUTPUT_DIR = os.path.join(BASE_DIR, 'output')
MODEL_DIR = os.path.join(BASE_DIR, 'models')
SUBDIR = 'flower_photos'

# Ensure directories exist
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)

# %%
# Load and preprocess dataset
def load_dataset(data_dir):
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
        data_dir,
        subset="training",
        seed=RANDOM_STATE,
        image_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=BATCH_SIZE,
        validation_split=TEST_SIZE,
    )

    test_ds = tf.keras.preprocessing.image_dataset_from_directory(
        data_dir,
        subset="validation",
        seed=RANDOM_STATE,
        image_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=BATCH_SIZE,
        validation_split=TEST_SIZE,
    )
    
    return train_ds, test_ds

# %%
# Load and preprocess dataset
def load_dataset(data_dir):
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
        data_dir,
        subset="training",
        seed=RANDOM_STATE,
        image_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=BATCH_SIZE,
        validation_split=TEST_SIZE,
    )

    test_ds = tf.keras.preprocessing.image_dataset_from_directory(
        data_dir,
        subset="validation",
        seed=RANDOM_STATE,
        image_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=BATCH_SIZE,
        validation_split=TEST_SIZE,
    )
    
    return train_ds, test_ds

# %%
# Performance optimization for dataset
def configure_dataset(ds, augment=False):
    if augment:
        # Data augmentation layers
        data_augmentation = tf.keras.Sequential([
            RandomFlip('horizontal'),
            RandomRotation(0.2),
            RandomZoom(0.2),
        ])
        
        ds = ds.map(
            lambda x, y: (data_augmentation(x, training=True), y), 
            num_parallel_calls=tf.data.AUTOTUNE
        )
    
    return ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# Create advanced custom CNN model
def create_custom_cnn_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    
    # Preprocessing and augmentation
    x = Rescaling(1./255)(inputs)
    
    # First Convolutional Block
    x = Conv2D(64, (3,3), padding='same', kernel_regularizer=l2(L2_RATE))(x)
    x = LeakyReLU(negative_slope=0.1)(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2,2), padding='same')(x)
    x = Dropout(0.25)(x)
    
    # Second Convolutional Block
    x = Conv2D(128, (3,3), padding='valid', kernel_regularizer=l2(L2_RATE))(x)
    x = LeakyReLU(negative_slope=0.1)(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2,2), padding='valid')(x)
    x = Dropout(0.3)(x)
    
    # Third Convolutional Block
    x = Conv2D(256, (3,3), padding='valid', kernel_regularizer=l2(L2_RATE))(x)
    x = LeakyReLU(negative_slope=0.1)(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2,2), padding='valid')(x)
    x = Dropout(0.35)(x)
    
    # Fourth Convolutional Block
    x = Conv2D(512, (3,3), padding='valid', kernel_regularizer=l2(L2_RATE))(x)
    x = LeakyReLU(negative_slope=0.1)(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2,2), padding='valid')(x)
    x = Dropout(0.4)(x)
    
    # Fifth Convolutional Block
    x = Conv2D(1024, (3,3), padding='valid', kernel_regularizer=l2(L2_RATE))(x)
    x = LeakyReLU(negative_slope=0.1)(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)
    
    # Fully Connected Layers 
    x = Flatten()(x)
    
    # Head Layers
    x = Dense(1024, kernel_regularizer=l2(L2_RATE))(x)
    x = LeakyReLU(negative_slope=0.1)(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    
    x = Dense(256, kernel_regularizer=l2(L2_RATE))(x)
    x = LeakyReLU(negative_slope=0.1)(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    
    # Output Layer
    outputs = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
# Main training function
def train_model():
    # Load dataset
    data_dir = os.path.join(INPUT_DIR, SUBDIR)
    train_ds, test_ds = load_dataset(data_dir)
    
    # Get class names
    class_names = train_ds.class_names
    num_classes = len(class_names)
    
    # Configure datasets
    train_ds = configure_dataset(train_ds, augment=True)
    test_ds = configure_dataset(test_ds)
    
    # Create model
    model = create_custom_cnn_model(
        input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), 
        num_classes=num_classes
    )
    
    # Model Summary
    model.summary()
    
    # Compile model
    model.compile(
        optimizer=Adam(learning_rate=LEARNING_RATE),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    
    # Callbacks
    # checkpoint_path = os.path.join(MODEL_DIR, SUBDIR, 'best_custom_model.keras')
    checkpoint_path = os.path.normpath(os.path.join(MODEL_DIR, SUBDIR, 'best_custom_model.keras'))

    os.makedirs(os.path.dirname(checkpoint_path), exist_ok=True)
    
    model_checkpoint = ModelCheckpoint(
        checkpoint_path,
        monitor='val_accuracy',
        mode='max',
        save_best_only=True,
        verbose=1
    )
    
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=PATIENCE,
        restore_best_weights=True,
        verbose=1
    )
    
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    )
    
    csv_logger = CSVLogger(
        os.path.join(OUTPUT_DIR, 'custom_cnn_training_log.csv'), 
        separator=',', 
        append=False
    )
    
    # Train model
    history = model.fit(
        train_ds, 
        epochs=EPOCHS, 
        validation_data=test_ds,
        callbacks=[
            model_checkpoint, 
            early_stopping, 
            reduce_lr,
            csv_logger
        ]
    )
    
    # Evaluate model
    test_loss, test_accuracy = model.evaluate(test_ds)
    print(f'Test accuracy: {test_accuracy * 100:.2f}%')
    
    # Plot training history
    plt.figure(figsize=(12, 4))
    
    # Accuracy plot
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    
    # Loss plot
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIR, 'custom_cnn_training_history.png'))
    plt.close()
    
    return model, history

# %%
# Run the training
if __name__ == '__main__':
    model, history = train_model()
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling_1 (Rescaling)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_7 (LeakyReLU)       │ (None, 224, 224, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 224, 224, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 110, 110, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_8 (LeakyReLU)       │ (None, 110, 110, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 110, 110, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 55, 55, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 55, 55, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 53, 53, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_9 (LeakyReLU)       │ (None, 53, 53, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 53, 53, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 26, 26, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 26, 26, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 24, 24, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_10 (LeakyReLU)      │ (None, 24, 24, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 24, 24, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 12, 12, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 12, 12, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 10, 10, 1024)   │     4,719,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_11 (LeakyReLU)      │ (None, 10, 10, 1024)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 10, 10, 1024)   │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 10, 10, 1024)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 102400)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1024)           │   104,858,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_12 (LeakyReLU)      │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_13 (LeakyReLU)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 111,405,957 (424.98 MB)
#  Trainable params: 111,399,429 (424.96 MB)
#  Non-trainable params: 6,528 (25.50 KB)
# Epoch 1/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3473 - loss: 2.6015
# Epoch 1: val_accuracy improved from -inf to 0.26158, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 678s 2s/step - accuracy: 0.3474 - loss: 2.6010 - val_accuracy: 0.2616 - val_loss: 3.0876 - learning_rate: 1.0000e-04
# Epoch 2/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4176 - loss: 2.1787
# Epoch 2: val_accuracy improved from 0.26158 to 0.35286, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 673s 2s/step - accuracy: 0.4176 - loss: 2.1786 - val_accuracy: 0.3529 - val_loss: 2.5216 - learning_rate: 1.0000e-04
# Epoch 3/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4668 - loss: 2.0491
# Epoch 3: val_accuracy did not improve from 0.35286
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 650s 2s/step - accuracy: 0.4668 - loss: 2.0490 - val_accuracy: 0.3379 - val_loss: 3.5250 - learning_rate: 1.0000e-04
# Epoch 4/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4848 - loss: 1.8909
# Epoch 4: val_accuracy did not improve from 0.35286
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 662s 2s/step - accuracy: 0.4848 - loss: 1.8909 - val_accuracy: 0.3270 - val_loss: 3.8183 - learning_rate: 1.0000e-04
# Epoch 5/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5242 - loss: 1.8351
# Epoch 5: val_accuracy improved from 0.35286 to 0.36921, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 677s 2s/step - accuracy: 0.5242 - loss: 1.8351 - val_accuracy: 0.3692 - val_loss: 3.1418 - learning_rate: 1.0000e-04
# Epoch 6/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5359 - loss: 1.7160
# Epoch 6: val_accuracy improved from 0.36921 to 0.40872, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 699s 2s/step - accuracy: 0.5359 - loss: 1.7161 - val_accuracy: 0.4087 - val_loss: 2.8822 - learning_rate: 1.0000e-04
# Epoch 7/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5719 - loss: 1.6345
# Epoch 7: val_accuracy improved from 0.40872 to 0.41281, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 670s 2s/step - accuracy: 0.5719 - loss: 1.6345 - val_accuracy: 0.4128 - val_loss: 2.4689 - learning_rate: 1.0000e-04
# Epoch 8/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6047 - loss: 1.5646
# Epoch 8: val_accuracy improved from 0.41281 to 0.42507, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 666s 2s/step - accuracy: 0.6047 - loss: 1.5646 - val_accuracy: 0.4251 - val_loss: 2.6877 - learning_rate: 1.0000e-04
# Epoch 9/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6025 - loss: 1.5330
# Epoch 9: val_accuracy did not improve from 0.42507
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 658s 2s/step - accuracy: 0.6025 - loss: 1.5331 - val_accuracy: 0.4196 - val_loss: 2.4491 - learning_rate: 1.0000e-04
# Epoch 10/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6395 - loss: 1.4848
# Epoch 10: val_accuracy improved from 0.42507 to 0.51362, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 667s 2s/step - accuracy: 0.6395 - loss: 1.4848 - val_accuracy: 0.5136 - val_loss: 2.1706 - learning_rate: 1.0000e-04
# Epoch 11/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6201 - loss: 1.5070
# Epoch 11: val_accuracy improved from 0.51362 to 0.52316, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 666s 2s/step - accuracy: 0.6202 - loss: 1.5069 - val_accuracy: 0.5232 - val_loss: 2.1061 - learning_rate: 1.0000e-04
# Epoch 12/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6789 - loss: 1.3606
# Epoch 12: val_accuracy improved from 0.52316 to 0.55313, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 665s 2s/step - accuracy: 0.6789 - loss: 1.3606 - val_accuracy: 0.5531 - val_loss: 2.0490 - learning_rate: 1.0000e-04
# Epoch 13/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7040 - loss: 1.3276
# Epoch 13: val_accuracy did not improve from 0.55313
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 658s 2s/step - accuracy: 0.7040 - loss: 1.3276 - val_accuracy: 0.5095 - val_loss: 2.2304 - learning_rate: 1.0000e-04
# Epoch 14/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7128 - loss: 1.2745
# Epoch 14: val_accuracy did not improve from 0.55313
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 658s 2s/step - accuracy: 0.7128 - loss: 1.2745 - val_accuracy: 0.5450 - val_loss: 2.1880 - learning_rate: 1.0000e-04
# Epoch 15/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7517 - loss: 1.2178
# Epoch 15: val_accuracy did not improve from 0.55313
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 658s 2s/step - accuracy: 0.7517 - loss: 1.2178 - val_accuracy: 0.5286 - val_loss: 2.2654 - learning_rate: 1.0000e-04
# Epoch 16/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7604 - loss: 1.1868
# Epoch 16: val_accuracy improved from 0.55313 to 0.60354, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 668s 2s/step - accuracy: 0.7604 - loss: 1.1867 - val_accuracy: 0.6035 - val_loss: 2.0226 - learning_rate: 1.0000e-04
# Epoch 17/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7909 - loss: 1.1046
# Epoch 17: val_accuracy did not improve from 0.60354
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 658s 2s/step - accuracy: 0.7909 - loss: 1.1046 - val_accuracy: 0.5913 - val_loss: 2.2030 - learning_rate: 1.0000e-04
# Epoch 18/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8276 - loss: 1.0697
# Epoch 18: val_accuracy improved from 0.60354 to 0.62943, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 667s 2s/step - accuracy: 0.8276 - loss: 1.0696 - val_accuracy: 0.6294 - val_loss: 2.0347 - learning_rate: 1.0000e-04
# Epoch 19/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8625 - loss: 0.9872
# Epoch 19: val_accuracy did not improve from 0.62943
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 674s 2s/step - accuracy: 0.8625 - loss: 0.9872 - val_accuracy: 0.6240 - val_loss: 2.2080 - learning_rate: 1.0000e-04
# Epoch 20/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8597 - loss: 0.9826
# Epoch 20: val_accuracy did not improve from 0.62943
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 704s 2s/step - accuracy: 0.8597 - loss: 0.9826 - val_accuracy: 0.6049 - val_loss: 2.4614 - learning_rate: 1.0000e-04
# Epoch 21/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9070 - loss: 0.9156
# Epoch 21: val_accuracy did not improve from 0.62943
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 705s 2s/step - accuracy: 0.9070 - loss: 0.9156 - val_accuracy: 0.5899 - val_loss: 2.6491 - learning_rate: 1.0000e-04
# Epoch 22/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9239 - loss: 0.8664
# Epoch 22: val_accuracy improved from 0.62943 to 0.66076, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 693s 2s/step - accuracy: 0.9239 - loss: 0.8663 - val_accuracy: 0.6608 - val_loss: 2.2140 - learning_rate: 5.0000e-05
# Epoch 23/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9432 - loss: 0.8025
# Epoch 23: val_accuracy did not improve from 0.66076
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 659s 2s/step - accuracy: 0.9432 - loss: 0.8025 - val_accuracy: 0.6580 - val_loss: 2.2946 - learning_rate: 5.0000e-05
# Epoch 24/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9734 - loss: 0.7582
# Epoch 24: val_accuracy did not improve from 0.66076
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 658s 2s/step - accuracy: 0.9734 - loss: 0.7582 - val_accuracy: 0.6185 - val_loss: 2.4116 - learning_rate: 5.0000e-05
# Epoch 25/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9721 - loss: 0.7417
# Epoch 25: val_accuracy improved from 0.66076 to 0.66894, saving model to ..\models\flower_photos\best_custom_model.keras
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 667s 2s/step - accuracy: 0.9721 - loss: 0.7417 - val_accuracy: 0.6689 - val_loss: 2.2344 - learning_rate: 5.0000e-05
# Epoch 26/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9704 - loss: 0.7429
# Epoch 26: val_accuracy did not improve from 0.66894
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 658s 2s/step - accuracy: 0.9704 - loss: 0.7429 - val_accuracy: 0.6213 - val_loss: 2.8820 - learning_rate: 5.0000e-05
# Epoch 27/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9784 - loss: 0.7162
# Epoch 27: val_accuracy did not improve from 0.66894
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 657s 2s/step - accuracy: 0.9784 - loss: 0.7162 - val_accuracy: 0.6322 - val_loss: 2.6023 - learning_rate: 2.5000e-05
# Epoch 28/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9821 - loss: 0.6995
# Epoch 28: val_accuracy did not improve from 0.66894
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 657s 2s/step - accuracy: 0.9821 - loss: 0.6995 - val_accuracy: 0.6281 - val_loss: 2.6811 - learning_rate: 2.5000e-05
# Epoch 29/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9904 - loss: 0.6835
# Epoch 29: val_accuracy did not improve from 0.66894
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 657s 2s/step - accuracy: 0.9904 - loss: 0.6835 - val_accuracy: 0.6281 - val_loss: 2.6217 - learning_rate: 2.5000e-05
# Epoch 30/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9921 - loss: 0.6697
# Epoch 30: val_accuracy did not improve from 0.66894
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 658s 2s/step - accuracy: 0.9921 - loss: 0.6697 - val_accuracy: 0.6267 - val_loss: 2.7518 - learning_rate: 2.5000e-05
# Epoch 31/50
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9921 - loss: 0.6694
# Epoch 31: val_accuracy did not improve from 0.66894
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 658s 2s/step - accuracy: 0.9921 - loss: 0.6693 - val_accuracy: 0.6444 - val_loss: 2.4825 - learning_rate: 2.5000e-05
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 16.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 27s 289ms/step - accuracy: 0.6192 - loss: 1.9518
# Test accuracy: 60.35%
